# %% [markdown]
# # Svm RBF Algorithm

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.model_selection import GridSearchCV
import pandas as pd

# %%
dataCSV = pd.read_csv('../data/data_cleaned.tsv', sep='\t')

# %% [markdown]
# ### Features
# #### _Largura flagelo por comprimento flagelo_

# %%
X = dataCSV.iloc[:, [3,4]].values
y = dataCSV.iloc[:, 5].values

# %% [markdown]
# > Procurando os melhores parametros gamma/C para o problema

# %%
C_range = np.logspace(-2, 10, 13)
gamma_range = np.logspace(-9, 3, 13)
param_grid = dict(gamma=gamma_range, C=C_range)
cv = StratifiedShuffleSplit(n_splits=5, test_size=0.3)
grid = GridSearchCV(SVC(), param_grid=param_grid, cv=cv)
grid.fit(X, y)
print("The best parameters are %s with a score of %0.2f"
      % (grid.best_params_, grid.best_score_))
# Out:
# The best parameters are {'C': 10.0, 'gamma': 0.10000000000000001} with a score of 0.96

# %% [markdown]
# > _Iniciando os plots de gráfico_

# %%
x_min, x_max = X[:, 0].min(), X[:, 0].max() + 1
y_min, y_max = X[:, 1].min(), X[:, 1].max() + 1
h = (x_max / x_min)/100
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
 np.arange(y_min, y_max, h))

# %%
plt.subplot(1, 1, 1)
Z = grid.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)
plt.contourf(xx, yy, Z, cmap=plt.cm.Paired, alpha=0.6)
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Paired)
plt.xlabel('Comprimento flagelo')
plt.ylabel('Largura flagelo')
plt.xlim(xx.min(), xx.max())
plt.title('SVC RBF kernel')
plt.savefig('../graph/ComprimentoFlageloxLarguraFlagelo.png')
plt.show()

# %% [markdown]
# #### _Largura corpo x Largura flagelo_

# %%
X = dataCSV.iloc[:, [1,3]].values
y = dataCSV.iloc[:, 5].values

# %% [markdown]
# > Procurando os melhores parametros gamma/C para o problema

# %%
C_range = np.logspace(-2, 10, 13)
gamma_range = np.logspace(-9, 3, 13)
param_grid = dict(gamma=gamma_range, C=C_range)
cv = StratifiedShuffleSplit(n_splits=5, test_size=0.3)
grid = GridSearchCV(SVC(), param_grid=param_grid, cv=cv)
grid.fit(X, y)
print("The best parameters are %s with a score of %0.2f"
      % (grid.best_params_, grid.best_score_))
# Out:
# The best parameters are {'C': 10000000.0, 'gamma': 0.0001} with a score of 0.95

# %% [markdown]
# > _Iniciando os plots de gráfico_

# %%
x_min, x_max = X[:, 0].min(), X[:, 0].max() + 0.5
y_min, y_max = X[:, 1].min(), X[:, 1].max() + 0.5
h = (x_max / x_min)/100
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
 np.arange(y_min, y_max, h))

# %%
plt.subplot(1, 1, 1)
Z = grid.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)
plt.contourf(xx, yy, Z, cmap=plt.cm.Paired, alpha=0.7)
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Paired)
plt.xlabel('Comprimento corpo')
plt.ylabel('Comprimento flagelo')
plt.xlim(xx.min(), xx.max())
plt.title('SVC RBF kernel')
plt.savefig('../graph/ComprimentoCorpoxComprimentoFlagelo.png')
plt.show()

# %% [markdown]
# #### _Volume corpo x Largura Corpo_

# %%
dataVolumeCSV = pd.read_csv('../data/data_new_feature.tsv', sep='\t')
X = dataVolumeCSV.iloc[:, [1,2]].values
y = dataVolumeCSV.iloc[:, 3].values

# %% [markdown]
# > Procurando os melhores parametros gamma/C para o problema

# %%
C_range = np.logspace(-2, 10, 13)
gamma_range = np.logspace(-9, 3, 13)
param_grid = dict(gamma=gamma_range, C=C_range)
cv = StratifiedShuffleSplit(n_splits=5, test_size=0.3)
grid = GridSearchCV(SVC(), param_grid=param_grid, cv=cv)
grid.fit(X, y)
print("The best parameters are %s with a score of %0.2f"
      % (grid.best_params_, grid.best_score_))
# Out:
# The best parameters are {'C': 1000000.0, 'gamma': 1e-08} with a score of 0.96

# %% [markdown]
# > _Iniciando os plots de gráfico_

# %%
x_min, x_max = X[:, 0].min()-0.9, X[:, 0].max() + 0.5
y_min, y_max = X[:, 1].min()-0.9, X[:, 1].max() + 0.5
h = (x_max / x_min)/100
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
 np.arange(y_min, y_max, h))

# %%
plt.subplot(1, 1, 1)
Z = grid.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)
plt.contourf(xx, yy, Z, cmap=plt.cm.Paired, alpha=0.7)
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Paired)
plt.xlabel('Volume corpo')
plt.ylabel('Volume flagelo')
plt.xlim(xx.min(), xx.max())
plt.title('SVC RBF kernel')
plt.savefig('../graph/VolumeCorpoxVolumeFlagelo.png')
plt.show()
